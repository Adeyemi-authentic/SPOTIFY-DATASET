# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\USER\Downloads\Spotify Songs 2023.xlsx")
df
# Out:
#                               track_name             artists  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 945                         My Mind & Me        Selena Gomez             1
# 946            Bigger Than The Whole Sky        Taylor Swift             1
# 947                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 948                        En La De Ella  Feid, Sech, Jhayco             3
# 949                                Alone           Burna Boy             1
#
# ...

# %%
pd.set_option('display.max.rows',950)
pd.set_option('display.max.columns',24)

# %%
df
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 1                                                 LALA
# 2                                              vampire
# 3                                         Cruel Summer
# 4                                       WHERE SHE GOES
# 5                                             Sprinter
# 6                                      Ella Baila Sola
# 7                                             Columbia
# 8                                             fukumean
# 9                                      La Bebe - Remix
# 10                                           un x100to
# 11                                           Super Shy
# 12                                             Flowers
# 13                                            Daylight
# 14                                           As It Was
# 15                                           Kill Bill
# ...

# %%
df.shape
# Out:
# (950, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            950 non-null    object
#  1   artists               950 non-null    object
#  2   artist_count          950 non-null    int64
#  3   released_year         950 non-null    int64
#  4   released_month        950 non-null    int64
#  5   released_day          950 non-null    int64
#  6   in_spotify_playlists  950 non-null    int64
#  7   in_spotify_charts     950 non-null    int64
#  8   streams               950 non-null    object
#  9   in_apple_playlists    950 non-null    int64
#  10  in_apple_charts       950 non-null    int64
#  11  in_deezer_playlists   950 non-null    int64
#  12  in_deezer_charts      950 non-null    int64
#  13  in_shazam_charts      900 non-null    float64
#  14  bpm                   950 non-null    int64
# ...

# %%
spotify=df[['artists','track_name','artist_count','released_year','released_month','released_day','streams']]

# %%
spotify
# Out:
#                                                artists  \
# 0                                     Latto, Jung Kook
# 1                                          Myke Towers
# 2                                       Olivia Rodrigo
# 3                                         Taylor Swift
# 4                                            Bad Bunny
# 5                                    Dave, Central Cee
# 6                           Eslabon Armado, Peso Pluma
# 7                                              Quevedo
# 8                                                Gunna
# 9                                Peso Pluma, Yng Lvcas
# 10                           Bad Bunny, Grupo Frontera
# 11                                            NewJeans
# 12                                         Miley Cyrus
# 13                                       David Kushner
# 14                                        Harry Styles
# 15                                                 SZA
# ...

# %% [markdown]
# #### 1.Who are the top 20 most streamed songs and artists

# %%
spotify['streams'].astype("float")
# the astype method was unable to convert the string to float ,so we use pd.to_numeric function
spotify['streams']=pd.to_numeric(spotify['streams'],errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 spotify['streams'].astype("float")
#       2 # the astype method was unable to convert the string to float ,so we use pd.to_numeric function
#       3 spotify['streams']=pd.to_numeric(spotify['streams'],errors='coerce')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
spotify['streams']=pd.to_numeric(spotify['streams'],errors='coerce')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12352\1254402855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spotify['streams']=pd.to_numeric(spotify['streams'],errors='coerce')

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   artists         950 non-null    object
#  1   track_name      950 non-null    object
#  2   artist_count    950 non-null    int64
#  3   released_year   950 non-null    int64
#  4   released_month  950 non-null    int64
#  5   released_day    950 non-null    int64
#  6   streams         949 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 52.1+ KB

# %%
# to find artist with the highest streams
top_artist=spotify['streams'].idxmax()
top_artist
# Out:
# 52

# %%
df.loc[top_artist]
# Out:
# track_name              Blinding Lights
# artists                      The Weeknd
# artist_count                          1
# released_year                      2019
# released_month                       11
# released_day                         29
# in_spotify_playlists              43899
# in_spotify_charts                    69
# streams                      3703895074
# in_apple_playlists                  672
# in_apple_charts                     199
# in_deezer_playlists                3421
# in_deezer_charts                     20
# in_shazam_charts                    NaN
# bpm                                 171
# key                                  C#
# mode                              Major
# danceability_%                       50
# Name: 52, dtype: object

# %%
top20=spotify.sort_values(by='streams',ascending=False)
top20.head(20)
# Out:
#                           artists  \
# 52                     The Weeknd
# 176                    Ed Sheeran
# 83                  Lewis Capaldi
# 617                   Tones and I
# 38          Post Malone, Swae Lee
# 159           Drake, WizKid, Kyla
# 81   Justin Bieber, The Kid Laroi
# 137               Imagine Dragons
# 722      The Chainsmokers, Halsey
# 45          The Weeknd, Daft Punk
# 135                    Ed Sheeran
# 68                  Glass Animals
# 14                   Harry Styles
# 690  Shawn Mendes, Camila Cabello
# 321                  James Arthur
# 125         Billie Eilish, Khalid
# 124                  Harry Styles
# 404                      Dua Lipa
# 618                    Juice WRLD
# 70              The Neighbourhood
#
#                                         track_name  artist_count  \
# 52                                 Blinding Lights             1
# 176                                   Shape of You             1
# ...

# %%
top20['artists'].unique()
# Out:
# array(['The Weeknd', 'Ed Sheeran', 'Lewis Capaldi', 'Tones and I',
#        'Post Malone, Swae Lee', 'Drake, WizKid, Kyla',
#        'Justin Bieber, The Kid Laroi', 'Imagine Dragons',
#        'The Chainsmokers, Halsey', 'The Weeknd, Daft Punk',
#        'Glass Animals', 'Harry Styles', 'Shawn Mendes, Camila Cabello',
#        'James Arthur', 'Billie Eilish, Khalid', 'Dua Lipa', 'Juice WRLD',
#        'The Neighbourhood', 'The Chainsmokers, Coldplay', 'Queen',
#        'Lady Gaga, Bradley Cooper', 'Hozier', 'Post Malone',
#        'Justin Bieber', 'John Legend', 'OneRepublic', 'Vance Joy',
#        'Avicii', 'Ray Dalton, Ryan Lewis, Macklemore', 'Kendrick Lamar',
#        'Calvin Harris, Dua Lipa', 'Olivia Rodrigo', 'Eminem',
#        'Jack Harlow, Lil Nas X', 'Tom Odell', 'The Killers',
#        'Dua Lipa, DaBaby', 'J. Cole', 'Arctic Monkeys',
#        'Bad Bunny, Jhay Cortez', 'Maroon 5', 'Chris Molitor', 'Lil Nas X',
# ...

# %%
top20.head(50)['artists'].unique()
# Out:
# array(['The Weeknd', 'Ed Sheeran', 'Lewis Capaldi', 'Tones and I',
#        'Post Malone, Swae Lee', 'Drake, WizKid, Kyla',
#        'Justin Bieber, The Kid Laroi', 'Imagine Dragons',
#        'The Chainsmokers, Halsey', 'The Weeknd, Daft Punk',
#        'Glass Animals', 'Harry Styles', 'Shawn Mendes, Camila Cabello',
#        'James Arthur', 'Billie Eilish, Khalid', 'Dua Lipa', 'Juice WRLD',
#        'The Neighbourhood', 'The Chainsmokers, Coldplay', 'Queen',
#        'Lady Gaga, Bradley Cooper', 'Hozier', 'Post Malone',
#        'Justin Bieber', 'John Legend', 'OneRepublic', 'Vance Joy',
#        'Avicii', 'Ray Dalton, Ryan Lewis, Macklemore', 'Kendrick Lamar',
#        'Calvin Harris, Dua Lipa', 'Olivia Rodrigo', 'Eminem',
#        'Jack Harlow, Lil Nas X', 'Tom Odell', 'The Killers',
#        'Dua Lipa, DaBaby', 'J. Cole', 'Arctic Monkeys',
#        'Bad Bunny, Jhay Cortez', 'Maroon 5', 'Chris Molitor', 'Lil Nas X'],
#       dtype=object)

# %%
kendrick=spotify[spotify['artists'].str.contains('Kendrick')]
kendrick
# Out:
#                                              artists  \
# 107                         Kendrick Lamar, Jay Rock
# 233                         Kendrick Lamar, Beyoncï¿
# 626                        Kendrick Lamar, Baby Keem
# 669                                   Kendrick Lamar
# 760                                   Kendrick Lamar
# 762             Kendrick Lamar, Blxst, Amanda Reifer
# 765                                   Kendrick Lamar
# 766                           Kendrick Lamar, Sampha
# 768                                   Kendrick Lamar
# 771                      Kendrick Lamar, Kodak Black
# 773                                   Kendrick Lamar
# 776                    Kendrick Lamar, Taylour Paige
# 777               Kendrick Lamar, Sam Dew, Baby Keem
# 780                                   Kendrick Lamar
# 782  Kendrick Lamar, Ghostface Killah, Summer Walker
# 791                      Kendrick Lamar, Tanna Leone
# 794                                   Kendrick Lamar
# ...

# %% [markdown]
# #### Kendrick Lamar total streams

# %%
kendrick.streams.sum()
# Out:
# 5555903581.0

# %% [markdown]
# #### Dave total streams

# %%
dave=spotify[spotify['artists'].str.contains('Dave')]
dave
# Out:
#                artists track_name  artist_count  released_year  \
# 5    Dave, Central Cee   Sprinter             2           2023
# 699               Dave  Starlight             1           2022
#
#      released_month  released_day      streams
# 5                 6             1  183706234.0
# 699               3             3  229473310.0

# %%
dave.streams.sum()
# Out:
# 413179544.0

# %% [markdown]
# #### travis scott total streams

# %%
travis=spotify[spotify['artists'].str.contains('Travis Scott')]
travis
# Out:
#                                     artists  \
# 133  Travis Scott, Young Thug, Metro Boomin
# 418   Travis Scott, 21 Savage, Metro Boomin
# 465                       SZA, Travis Scott
# 478              Travis Scott, Metro Boomin
# 623                     Drake, Travis Scott
# 929          Drake, Travis Scott, 21 Savage
#
#                                             track_name  artist_count  \
# 133            Trance (with Travis Scott & Young Thug)             3
# 418  Niagara Falls (Foot or 2) [with Travis Scott &...             3
# 465                     Open Arms (feat. Travis Scott)             2
# 478             Raindrops (Insane) [with Travis Scott]             2
# 623                     Fair Trade (with Travis Scott)             2
# 929              Pussy & Millions (feat. Travis Scott)             3
#
#      released_year  released_month  released_day      streams
# 133           2022              12             2  276259178.0
# ...

# %%
travis.streams.sum()
# Out:
# 1523331004.0

# %%
SZA=spotify[spotify['artists'].str.contains('SZA')]
SZA
# Out:
#                   artists                                    track_name  \
# 15                    SZA                                     Kill Bill
# 94                    SZA                                        Snooze
# 327                   SZA                                           Low
# 347                   SZA                                Nobody Gets Me
# 383                   SZA                                         Shirt
# 413                   SZA                                         Blind
# 429                   SZA                                     Good Days
# 452                   SZA                                Seek & Destroy
# 453                   SZA                                 Love Language
# 455      SZA, Don Toliver                      Used (feat. Don Toliver)
# 460  SZA, Phoebe Bridgers  Ghost in the Machine (feat. Phoebe Bridgers)
# 461                   SZA                                       Special
# ...

# %%
SZA.streams.sum()
# Out:
# 6493011189.0

# %%
spot_groupby_frame=spotify.groupby('released_year')

# %%
Total_stream_by_year=spotify.groupby('released_year').max(10).sort_values(by='streams',ascending=False)
Total_stream_by_year
# Out:
#                artist_count  released_month  released_day       streams
# released_year
# 2019                      3              12            31  3.703895e+09
# 2017                      3              12            31  3.562544e+09
# 2018                      2              11            29  2.887242e+09
# 2016                      3              11            31  2.713922e+09
# 2021                      8              12            30  2.665344e+09
# 2020                      3              12            30  2.557976e+09
# 2022                      7              12            31  2.513188e+09
# 2012                      2              12            20  2.282771e+09
# 2014                      1              12            28  2.280566e+09
# 1975                      1              10            31  2.197011e+09
# 2013                      3              12            25  2.135158e+09
# 2015                      1              11            30  2.123310e+09
# ...

# %% [markdown]
# ### from our output we can see that from our outputs most of the songss with high streams are released towards he end of the month

# %% [markdown]
# #### Songs with the highest streams were released in the last quarter of the year (Months like November,December,September recorded the highest number of streams)

# %%
spotify.describe()
# Out:
#        artist_count  released_year  released_month  released_day       streams
# count    950.000000     950.000000      950.000000    950.000000  9.490000e+02
# mean       1.556842    2018.223158        6.040000     13.903158  5.148538e+08
# std        0.893974      11.130545        3.568165      9.193912  5.675054e+08
# min        1.000000    1930.000000        1.000000      1.000000  2.762000e+03
# 25%        1.000000    2020.000000        3.000000      6.000000  1.417210e+08
# 50%        1.000000    2022.000000        6.000000     13.000000  2.902286e+08
# 75%        2.000000    2022.000000        9.000000     22.000000  6.740727e+08
# max        8.000000    2023.000000       12.000000     31.000000  3.703895e+09

# %% [markdown]
# #### songs released in 2023,2022,2021,2019,2017 and their top 10 each

# %%
y2023=spotify[spotify['released_year']==2023]
y2023
# Out:
#                                                artists  \
# 0                                     Latto, Jung Kook
# 1                                          Myke Towers
# 2                                       Olivia Rodrigo
# 4                                            Bad Bunny
# 5                                    Dave, Central Cee
# 6                           Eslabon Armado, Peso Pluma
# 7                                              Quevedo
# 8                                                Gunna
# 9                                Peso Pluma, Yng Lvcas
# 10                           Bad Bunny, Grupo Frontera
# 11                                            NewJeans
# 12                                         Miley Cyrus
# 13                                       David Kushner
# 16                                               Jimin
# 17            Gabito Ballesteros, Junior H, Peso Pluma
# 18                                        Taylor Swift
# ...

# %%
y2023.sort_values(by='streams',ascending=False)
# Out:
#                                                artists  \
# 12                                         Miley Cyrus
# 6                           Eslabon Armado, Peso Pluma
# 130                                  Shakira, Bizarrap
# 31                                    Karol G, Shakira
# 9                                Peso Pluma, Yng Lvcas
# 46                           Ariana Grande, The Weeknd
# 10                           Bad Bunny, Grupo Frontera
# 157                          Natanael Cano, Peso Pluma
# 128                                           NewJeans
# 25                                       Morgan Wallen
# 13                                       David Kushner
# 16                                               Jimin
# 60                            Rauw Alejandro, ROSALï¿½
# 37                                Junior H, Peso Pluma
# 178                             Oscar Maydon, Junior H
# 4                                            Bad Bunny
# ...

# %%
y2023.sort_values(by='streams',ascending=False).head(10)
# Out:
#                         artists                             track_name  \
# 12                  Miley Cyrus                                Flowers
# 6    Eslabon Armado, Peso Pluma                        Ella Baila Sola
# 130           Shakira, Bizarrap  Shakira: Bzrp Music Sessions, Vol. 53
# 31             Karol G, Shakira                                    TQG
# 9         Peso Pluma, Yng Lvcas                        La Bebe - Remix
# 46    Ariana Grande, The Weeknd                    Die For You - Remix
# 10    Bad Bunny, Grupo Frontera                              un x100to
# 157   Natanael Cano, Peso Pluma                                    PRC
# 128                    NewJeans                                    OMG
# 25                Morgan Wallen                             Last Night
#
#      artist_count  released_year  released_month  released_day       streams
# 12              1           2023               1            12  1.316856e+09
# ...

# %%
y2022=spotify[spotify['released_year']==2022]
y2022
# Out:
#                                                artists  \
# 14                                        Harry Styles
# 15                                                 SZA
# 23                                 Rï¿½ï¿½ma, Selena G
# 29                 The Weeknd, 21 Savage, Metro Boomin
# 30                                        Taylor Swift
# 39                            Bebe Rexha, David Guetta
# 43                                         OneRepublic
# 54                                       Manuel Turizo
# 59                        Charlie Puth, BTS, Jung Kook
# 61                                         Ozuna, Feid
# 63                                        Taylor Swift
# 64                                            Libianca
# 69                                                JVKE
# 71                                   Bizarrap, Quevedo
# 73                                                d4vd
# 74                               Sam Smith, Kim Petras
# ...

# %%
y2022.sort_values(by='streams',ascending=False)
# Out:
#                                                artists  \
# 14                                        Harry Styles
# 84                         Chencho Corleone, Bad Bunny
# 71                                   Bizarrap, Quevedo
# 189                                          Bad Bunny
# 74                               Sam Smith, Kim Petras
# 54                                       Manuel Turizo
# 15                                                 SZA
# 143                          Bomba Estï¿½ï¿½reo, Bad B
# 39                            Bebe Rexha, David Guetta
# 43                                         OneRepublic
# 236                                          Bad Bunny
# 30                                        Taylor Swift
# 250                                               Joji
# 374                                          Bad Bunny
# 23                                 Rï¿½ï¿½ma, Selena G
# 268                                            Karol G
# ...

# %%
y2022.sort_values(by='streams',ascending=False).head(10)
# Out:
#                          artists                             track_name  \
# 14                  Harry Styles                              As It Was
# 84   Chencho Corleone, Bad Bunny                        Me Porto Bonito
# 71             Bizarrap, Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52
# 189                    Bad Bunny                      Titi Me Preguntï¿
# 74         Sam Smith, Kim Petras              Unholy (feat. Kim Petras)
# 54                 Manuel Turizo                             La Bachata
# 15                           SZA                              Kill Bill
# 143    Bomba Estï¿½ï¿½reo, Bad B                          Ojitos Lindos
# 39      Bebe Rexha, David Guetta                        I'm Good (Blue)
# 43                   OneRepublic                        I Ain't Worried
#
#      artist_count  released_year  released_month  released_day       streams
# 14              1           2022               3            31  2.513188e+09
# ...

# %%
y2021=spotify[spotify['released_year']==2021].sort_values(by='streams',ascending=False)
y2021
# Out:
#      released_year                                            artists  \
# 81            2021                       Justin Bieber, The Kid Laroi
# 510           2021                                     Olivia Rodrigo
# 532           2021                                     Olivia Rodrigo
# 407           2021                             Jack Harlow, Lil Nas X
# 513           2021                                      SZA, Doja Cat
# 551           2021               Justin Bieber, Daniel Caesar, Giveon
# 243           2021                                              Adele
# 431           2021                                           Doja Cat
# 504           2021                                            Farruko
# 271           2021                                         Ed Sheeran
# 419           2021                                          Bad Bunny
# 562           2021                                     Olivia Rodrigo
# ...

# %%
y2021.head(10)
# Out:
#      released_year                               artists  \
# 81            2021          Justin Bieber, The Kid Laroi
# 510           2021                        Olivia Rodrigo
# 532           2021                        Olivia Rodrigo
# 407           2021                Jack Harlow, Lil Nas X
# 513           2021                         SZA, Doja Cat
# 551           2021  Justin Bieber, Daniel Caesar, Giveon
# 243           2021                                 Adele
# 431           2021                              Doja Cat
# 504           2021                               Farruko
# 271           2021                            Ed Sheeran
#
#                                  track_name  artist_count  released_month  \
# 81                STAY (with Justin Bieber)             2               7
# 510                                good 4 u             1               5
# 532                         drivers license             1               1
# ...

# %%
y2019=spotify[spotify['released_year']==2019].sort_values(by='streams',ascending=False)
y2019
# Out:
#                             artists  \
# 52                       The Weeknd
# 617                     Tones and I
# 690    Shawn Mendes, Camila Cabello
# 124                    Harry Styles
# 404                        Dua Lipa
# 184                     Post Malone
# 638                        Maroon 5
# 588                   Lewis Capaldi
# 692                    Harry Styles
# 365             J Balvin, Bad Bunny
# 787                Bad Bunny, Tainy
# 607                     Masked Wolf
# 387                     Halsey, BTS
# 747                    Harry Styles
# 622                 Duncan Laurence
# 156                     Chris Brown
# 630                        Doja Cat
# 753                    Harry Styles
# 3                      Taylor Swift
# 517                            Ckay
# 565       The Weeknd, Gesaffelstein
# 683                        Labrinth
# 660                        Labrinth
# 546             Ckay, AX'EL, Dj Yo!
# 661                        Labrinth
# ...

# %%
y2019.head(10)
# Out:
#                           artists        track_name  artist_count  \
# 52                     The Weeknd   Blinding Lights             1
# 617                   Tones and I      Dance Monkey             1
# 690  Shawn Mendes, Camila Cabello         Seï¿½ï¿½o             2
# 124                  Harry Styles  Watermelon Sugar             1
# 404                      Dua Lipa   Don't Start Now             1
# 184                   Post Malone           Circles             1
# 638                      Maroon 5          Memories             1
# 588                 Lewis Capaldi     Before You Go             1
# 692                  Harry Styles         Adore You             1
# 365           J Balvin, Bad Bunny       LA CANCIï¿½             2
#
#      released_year  released_month  released_day       streams
# 52            2019              11            29  3.703895e+09
# 617           2019               5            10  2.864792e+09
# ...

# %%
y2018=spotify[spotify['released_year']==2018].sort_values(by='streams',ascending=False)
y2018
# Out:
#                        artists                                     track_name  \
# 83               Lewis Capaldi                              Someone You Loved
# 38       Post Malone, Swae Lee  Sunflower - Spider-Man: Into the Spider-Verse
# 631  Lady Gaga, Bradley Cooper                                        Shallow
# 289                 The Weeknd                               Call Out My Name
# 167              Alec Benjamin                             Let Me Down Slowly
# 715               XXXTENTACION                                           Hope
# 853                       Joji                       SLOW DANCING IN THE DARK
# 920                girl in red                     we fell in love in october
# 285  The Weeknd, Gesaffelstein                              I Was Never There
# 542          The Neighbourhood                                       Softcore
#
#      artist_count  released_year  released_month  released_day       streams
# ...

# %%
y2018.head(10)
# Out:
#                        artists                                     track_name  \
# 83               Lewis Capaldi                              Someone You Loved
# 38       Post Malone, Swae Lee  Sunflower - Spider-Man: Into the Spider-Verse
# 631  Lady Gaga, Bradley Cooper                                        Shallow
# 289                 The Weeknd                               Call Out My Name
# 167              Alec Benjamin                             Let Me Down Slowly
# 715               XXXTENTACION                                           Hope
# 853                       Joji                       SLOW DANCING IN THE DARK
# 920                girl in red                     we fell in love in october
# 285  The Weeknd, Gesaffelstein                              I Was Never There
# 542          The Neighbourhood                                       Softcore
#
#      artist_count  released_year  released_month  released_day       streams
# ...

# %%
y2017=spotify[spotify['released_year']==2017].sort_values(by='streams',ascending=False)
y2017
# Out:
#                             artists                track_name  artist_count  \
# 176                      Ed Sheeran              Shape of You             1
# 137                 Imagine Dragons                  Believer             1
# 135                      Ed Sheeran                   Perfect             1
# 125           Billie Eilish, Khalid      lovely - Bonus Track             2
# 618                      Juice WRLD              Lucid Dreams             1
# 721      The Chainsmokers, Coldplay  Something Just Like This             2
# 669                  Kendrick Lamar                   HUMBLE.             1
# 400         Calvin Harris, Dua Lipa  One Kiss (with Dua Lipa)             2
# 103      Dua Lipa, Elton John, Pnau   Cold Heart - PNAU Remix             3
# 523                       Mï¿½ï¿½ne                    Beggin             1
# 104                         Ruth B.                Dandelions             1
# ...

# %%
y2017.head(10)
# Out:
#                         artists                track_name  artist_count  \
# 176                  Ed Sheeran              Shape of You             1
# 137             Imagine Dragons                  Believer             1
# 135                  Ed Sheeran                   Perfect             1
# 125       Billie Eilish, Khalid      lovely - Bonus Track             2
# 618                  Juice WRLD              Lucid Dreams             1
# 721  The Chainsmokers, Coldplay  Something Just Like This             2
# 669              Kendrick Lamar                   HUMBLE.             1
# 400     Calvin Harris, Dua Lipa  One Kiss (with Dua Lipa)             2
# 103  Dua Lipa, Elton John, Pnau   Cold Heart - PNAU Remix             3
# 523                   Mï¿½ï¿½ne                    Beggin             1
#
#      released_year  released_month  released_day       streams
# 176           2017               1             6  3.562544e+09
# ...

# %%
spotify.set_index('released_year',inplace=True)

# %%
spotify
# Out:
#                                                          artists  \
# released_year
# 2023                                            Latto, Jung Kook
# 2023                                                 Myke Towers
# 2023                                              Olivia Rodrigo
# 2019                                                Taylor Swift
# 2023                                                   Bad Bunny
# 2023                                           Dave, Central Cee
# 2023                                  Eslabon Armado, Peso Pluma
# 2023                                                     Quevedo
# 2023                                                       Gunna
# 2023                                       Peso Pluma, Yng Lvcas
# 2023                                   Bad Bunny, Grupo Frontera
# 2023                                                    NewJeans
# 2023                                                 Miley Cyrus
# ...

# %% [markdown]
# #### to get each year maximum stream

# %%
spotify.groupby('released_year')

# %%
spotify.groupby('released_year').streams.max()
# Out:
# released_year
# 1930    9.059852e+07
# 1942    3.955914e+08
# 1946    3.897720e+08
# 1950    4.732483e+08
# 1952    3.955914e+08
# 1957    7.413016e+08
# 1958    7.692135e+08
# 1959    4.463901e+08
# 1963    6.638321e+08
# 1968    1.145728e+09
# 1970    5.200345e+08
# 1971    4.604928e+08
# 1973    8.385868e+08
# 1975    2.197011e+09
# 1979    4.039395e+08
# 1982    1.959185e+08
# 1983    1.593271e+09
# 1984    1.479115e+09
# 1985    1.205952e+09
# 1986    7.041711e+08
# 1987    1.553498e+09
# 1991    1.690193e+09
# 1992    1.271293e+09
# 1994    1.449779e+09
# 1995    1.357609e+09
# 1996    1.069331e+08
# 1997    1.037625e+08
# 1998    1.284943e+09
# 1999    1.755214e+09
# 2000    1.624166e+09
# 2002    1.829993e+09
# 2003    1.806618e+09
# 2004    1.241559e+09
# 2005    1.805775e+08
# 2007    1.217121e+09
# 2008    1.592910e+09
# 2010    1.641427e+09
# 2011    1.953534e+09
# 2012    2.282771e+09
# 2013    2.135158e+09
# 2014    2.280566e+09
# 2015    2.123310e+09
# ...

# %%
spotify.reset_index(inplace=True)
